# %%
import pandas as pd

# %%
sfw = pd.read_csv('SFWPHYFINAL3456.csv')

# %%
sfw
# Out:
#               Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0       ADNAN     points    DIGANTA     points       SAJIB     points
# 1     Alisson        NaN       Pope        NaN     Alisson        NaN
# 2      Arnold        NaN     Arnold        NaN      Coufal        NaN
# 3   Cresswell        NaN     Coufal        NaN     Arnold         NaN
# 4      Dallas        NaN     Dallas        NaN      Taylor        NaN
# 5         Son        NaN       Mane        NaN         KDB        NaN
# 6     Lingard        NaN      Salah        NaN   Greenwood        NaN
# 7      Torres        NaN    Lingard        NaN       Salah        NaN
# 8    Raphinha        NaN   Harrison        NaN     Willock        NaN
# 9        Kane        NaN       Kane        NaN  Iheanacho         NaN
# 10  Iheanacho        NaN    Bamford        NaN     Antonio        NaN
# 11    Antonio        NaN       Wood        NaN     Bamford        NaN
#
# ...

# %%
sfw.drop(['Unnamed: 1', 'Unnamed: 3','Unnamed: 5','Unnamed: 7','Unnamed: 9'], axis =1, inplace = True)

# %%
sfw
# Out:
#               Unnamed: 2  Unnamed: 4 Unnamed: 6 Unnamed: 8  Unnamed: 10  \
# 0       ADNAN    DIGANTA       SAJIB     TAHMID      SHUVO          NaN
# 1     Alisson       Pope     Alisson  Fabianski    Alisson          NaN
# 2      Arnold     Arnold      Coufal  Robertson     Dallas          NaN
# 3   Cresswell     Coufal     Arnold      Lowton     Arnold          NaN
# 4      Dallas     Dallas      Taylor     Dallas        Mee          NaN
# 5         Son       Mane         KDB   Harrison      Salah          NaN
# 6     Lingard      Salah   Greenwood       Bale        Son          NaN
# 7      Torres    Lingard       Salah      Salah    Lingard          NaN
# 8    Raphinha   Harrison     Willock    Lingard   Raphinha          NaN
# 9        Kane       Kane  Iheanacho        Kane       Kane          NaN
# 10  Iheanacho    Bamford     Antonio    Antonio    Bamford          NaN
# 11    Antonio       Wood     Bamford        DCL    Antonio          NaN
#
# ...

# %%
sfw.drop(['Unnamed: 10', 'Unnamed: 11','Unnamed: 13','Unnamed: 15','Unnamed: 17','Unnamed: 19','Unnamed: 21'], axis =1, inplace = True)

# %%
sfw
# Out:
#               Unnamed: 2  Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 12  \
# 0       ADNAN    DIGANTA       SAJIB     TAHMID      SHUVO       Limon
# 1     Alisson       Pope     Alisson  Fabianski    Alisson   Fabianski
# 2      Arnold     Arnold      Coufal  Robertson     Dallas      Dallas
# 3   Cresswell     Coufal     Arnold      Lowton     Arnold   Tarkowski
# 4      Dallas     Dallas      Taylor     Dallas        Mee     Arnold
# 5         Son       Mane         KDB   Harrison      Salah        Pepe
# 6     Lingard      Salah   Greenwood       Bale        Son       Salah
# 7      Torres    Lingard       Salah      Salah    Lingard      Mahrez
# 8    Raphinha   Harrison     Willock    Lingard   Raphinha    Harrison
# 9        Kane       Kane  Iheanacho        Kane       Kane        Kane
# 10  Iheanacho    Bamford     Antonio    Antonio    Bamford     Antonio
# 11    Antonio       Wood     Bamford        DCL    Antonio        Wood
#
# ...

# %%
sfw.drop([1,4,10,16,20,21,22,23,24,25,26], axis = 0, inplace = True)

# %%
sfw
# Out:
#               Unnamed: 2  Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 12  \
# 0       ADNAN    DIGANTA       SAJIB     TAHMID      SHUVO       Limon
# 1     Alisson       Pope     Alisson  Fabianski    Alisson   Fabianski
# 2      Arnold     Arnold      Coufal  Robertson     Dallas      Dallas
# 3   Cresswell     Coufal     Arnold      Lowton     Arnold   Tarkowski
# 4      Dallas     Dallas      Taylor     Dallas        Mee     Arnold
# 5         Son       Mane         KDB   Harrison      Salah        Pepe
# 6     Lingard      Salah   Greenwood       Bale        Son       Salah
# 7      Torres    Lingard       Salah      Salah    Lingard      Mahrez
# 8    Raphinha   Harrison     Willock    Lingard   Raphinha    Harrison
# 9        Kane       Kane  Iheanacho        Kane       Kane        Kane
# 10  Iheanacho    Bamford     Antonio    Antonio    Bamford     Antonio
# 11    Antonio       Wood     Bamford        DCL    Antonio        Wood
#
# ...

# %%
sfw.columns = sfw.iloc[0]
sfw.drop([0], axis=0, inplace = True)
sfw
# Out:
# 0       ADNAN   DIGANTA       SAJIB     TAHMID     SHUVO      Limon  \
# 1     Alisson      Pope     Alisson  Fabianski   Alisson  Fabianski
# 2      Arnold    Arnold      Coufal  Robertson    Dallas     Dallas
# 3   Cresswell    Coufal     Arnold      Lowton    Arnold  Tarkowski
# 4      Dallas    Dallas      Taylor     Dallas       Mee    Arnold
# 5         Son      Mane         KDB   Harrison     Salah       Pepe
# 6     Lingard     Salah   Greenwood       Bale       Son      Salah
# 7      Torres   Lingard       Salah      Salah   Lingard     Mahrez
# 8    Raphinha  Harrison     Willock    Lingard  Raphinha   Harrison
# 9        Kane      Kane  Iheanacho        Kane      Kane       Kane
# 10  Iheanacho   Bamford     Antonio    Antonio   Bamford    Antonio
# 11    Antonio      Wood     Bamford        DCL   Antonio       Wood
#
# 0       Shadman     Rayhan      Athoy     Tanvir
# 1          Leno       Leno    Meslier    Alisson
# 2        Dallas  Cresswell     Arnold  Cresswell
# ...

# %%
index = list(range(0,11))

sfw['index'] = index

# %%
sfw.set_index('index', drop = True, inplace = True)

# %%
sfw.reset_index(drop = True, inplace = True)
sfw
# Out:
# 0       ADNAN   DIGANTA       SAJIB     TAHMID     SHUVO      Limon  \
# 0     Alisson      Pope     Alisson  Fabianski   Alisson  Fabianski
# 1      Arnold    Arnold      Coufal  Robertson    Dallas     Dallas
# 2   Cresswell    Coufal     Arnold      Lowton    Arnold  Tarkowski
# 3      Dallas    Dallas      Taylor     Dallas       Mee    Arnold
# 4         Son      Mane         KDB   Harrison     Salah       Pepe
# 5     Lingard     Salah   Greenwood       Bale       Son      Salah
# 6      Torres   Lingard       Salah      Salah   Lingard     Mahrez
# 7    Raphinha  Harrison     Willock    Lingard  Raphinha   Harrison
# 8        Kane      Kane  Iheanacho        Kane      Kane       Kane
# 9   Iheanacho   Bamford     Antonio    Antonio   Bamford    Antonio
# 10    Antonio      Wood     Bamford        DCL   Antonio       Wood
#
# 0       Shadman     Rayhan      Athoy     Tanvir
# 0          Leno       Leno    Meslier    Alisson
# 1        Dallas  Cresswell     Arnold  Cresswell
# ...

# %%
players = ['ADNAN', 'DIGANTA', 'SAJIB', 'TAHMID', 'SHUVO', 'Limon', 'Shadman', 'Rayhan', 'Athoy', 'Tanvir']

# %%
Adnan = sfw['ADNAN'].to_list()
Diganta = sfw['DIGANTA'].to_list()
Sajib = sfw['SAJIB'].to_list()
Tahmid = sfw['TAHMID'].to_list()
Shuvo = sfw['SHUVO'].to_list()
Limon = sfw['Limon'].to_list()
Shadman = sfw['Shadman'].to_list()
Rayhan = sfw['Rayhan'].to_list()
Athoy = sfw['Athoy'].to_list()
Tanvir = sfw['Tanvir'].to_list()

# %%
PHY = Adnan + Diganta + Sajib + Tahmid + Shuvo
GEE = Limon + Shadman + Rayhan + Athoy + Tanvir

# %%
PHYCAP = ['Kane', 'Salah', 'Salah', 'Salah', 'Antonio']
GEECAP = ['Salah', 'Salah', 'Salah', 'Salah', 'Mane']

# %%
PHY = PHY + PHYCAP
GEE = GEE + GEECAP

# %%
#PHYSUB = ['McCarthy', 'Mitchell','Stones', 'Foden', 'Forster', 'Mitchell', 'Digne', 'DCL', 'Button', 'Mitchell', 'Targett', 'DCL', 'Button', 'Mitchell', 'Targett', 'Kane', 'Forster', 'Dias', 'Stones', 'Burke']

# %%
#GEESUB = ['Norris', 'Targett', 'Justin', 'DCL', 'Sanchez', 'Stones', 'Struijk', 'Gundogan', 'Martinez', 'Stones', 'Perreira', 'Zaha', 'Button', 'Targett', 'Mitchell', 'ESR', 'Forster', 'Holding', 'Stones', 'ESR']

# %%
for a in GEESUB:
    if a in GEE:
        GEE.remove(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1a57ebb65564> in <module>
# ----> 1 for a in GEESUB:
#       2     if a in GEE:
#       3         GEE.remove(a)
#
# NameError: name 'GEESUB' is not defined

# %%
for a in PHYSUB:
    if a in PHY:
        PHY.remove(a)

# %%
len(PHY)
# Out:
# 60

# %%
len(GEE)
# Out:
# 60

# %%
GEE.count('Fernandes')
# Out:
# 4

# %%
# GEE Differentials
for a in PHY:
    if a in GEE:
        GEE.remove(a)

# %%
GEE.sort()
GEE
# Out:
# ['Arnold ',
#  'Aubameyang ',
#  'Bamford',
#  'Cresswell',
#  'Foden',
#  'Greenwood',
#  'Ings',
#  'Leno',
#  'Leno',
#  'Mahrez',
#  'Mane',
#  'Meslier',
#  'Pepe',
#  'Pepe',
#  'Phillips',
#  'Phillips',
#  'Salah',
#  'Salah',
#  'Tarkowski',
#  'Wood']

# %%
GEE_dict={}

for item in GEE:
    
    GEE_dict[item] = GEE.count(item)

# %%
GEE_dict
# Out:
# {'Arnold ': 1,
#  'Aubameyang ': 1,
#  'Bamford': 1,
#  'Cresswell': 1,
#  'Foden': 1,
#  'Greenwood': 1,
#  'Ings': 1,
#  'Leno': 2,
#  'Mahrez': 1,
#  'Mane': 1,
#  'Meslier': 1,
#  'Pepe': 2,
#  'Phillips': 2,
#  'Salah': 2,
#  'Tarkowski': 1,
#  'Wood': 1}

# %%
GEE_differentials = pd.DataFrame(data = GEE_dict.items(), columns = ['Player', 'Count'])

# %%
GEE_differentials
# Out:
#          Player  Count
# 0       Arnold       1
# 1   Aubameyang       1
# 2       Bamford      1
# 3     Cresswell      1
# 4         Foden      1
# 5     Greenwood      1
# 6          Ings      1
# 7          Leno      2
# 8        Mahrez      1
# 9          Mane      1
# 10      Meslier      1
# 11         Pepe      2
# 12     Phillips      2
# 13        Salah      2
# 14    Tarkowski      1
# 15         Wood      1

# %%
# PHY Differentials
for a in GEE:
    if a in PHY:
        PHY.remove(a)

# %%
PHY.sort()
PHY
# Out:
# ['Alisson',
#  'Alisson',
#  'Antonio',
#  'Antonio',
#  'Coufal',
#  'DCL',
#  'Harrison',
#  'Iheanacho ',
#  'KDB',
#  'Kane',
#  'Kane',
#  'Kane',
#  'Lingard',
#  'Lowton',
#  'Mee',
#  'Pope',
#  'Raphinha',
#  'Robertson',
#  'Taylor',
#  'Torres']

# %%
PHY_dict={}

for item in PHY:
    
    PHY_dict[item] = PHY.count(item)

# %%
PHY_dict
# Out:
# {'Alisson': 2,
#  'Antonio': 2,
#  'Coufal': 1,
#  'DCL': 1,
#  'Harrison': 1,
#  'Iheanacho ': 1,
#  'KDB': 1,
#  'Kane': 3,
#  'Lingard': 1,
#  'Lowton': 1,
#  'Mee': 1,
#  'Pope': 1,
#  'Raphinha': 1,
#  'Robertson': 1,
#  'Taylor': 1,
#  'Torres': 1}

# %%
PHY_differentials = pd.DataFrame(data = PHY_dict.items(), columns = ['Player', 'Count'])

# %%
PHY_differentials
# Out:
#         Player  Count
# 0      Alisson      2
# 1      Antonio      2
# 2       Coufal      1
# 3          DCL      1
# 4     Harrison      1
# 5   Iheanacho       1
# 6          KDB      1
# 7         Kane      3
# 8      Lingard      1
# 9       Lowton      1
# 10         Mee      1
# 11        Pope      1
# 12    Raphinha      1
# 13   Robertson      1
# 14      Taylor      1
# 15      Torres      1

# %%
GEE_dict_sorted = sorted(GEE_dict.items(), key = lambda x:x[1], reverse = True)

# %%
GEE_dict_sorted
# Out:
# [('Leno', 2),
#  ('Pepe', 2),
#  ('Phillips', 2),
#  ('Salah', 2),
#  ('Arnold ', 1),
#  ('Aubameyang ', 1),
#  ('Bamford', 1),
#  ('Cresswell', 1),
#  ('Foden', 1),
#  ('Greenwood', 1),
#  ('Ings', 1),
#  ('Mahrez', 1),
#  ('Mane', 1),
#  ('Meslier', 1),
#  ('Tarkowski', 1),
#  ('Wood', 1)]

# %%
GEE_differentials_sorted = pd.DataFrame(data = GEE_dict_sorted, columns = ['Player', 'Count'])

# %%
GEE_differentials_sorted
# Out:
#          Player  Count
# 0          Leno      2
# 1          Pepe      2
# 2      Phillips      2
# 3         Salah      2
# 4       Arnold       1
# 5   Aubameyang       1
# 6       Bamford      1
# 7     Cresswell      1
# 8         Foden      1
# 9     Greenwood      1
# 10         Ings      1
# 11       Mahrez      1
# 12         Mane      1
# 13      Meslier      1
# 14    Tarkowski      1
# 15         Wood      1

# %%
PHY_dict_sorted = sorted(PHY_dict.items(), key = lambda x:x[1], reverse = True)

# %%
PHY_differentials_sorted = pd.DataFrame(data = PHY_dict_sorted, columns = ['Player', 'Count'])

# %%
PHY_differentials_sorted
# Out:
#         Player  Count
# 0         Kane      3
# 1      Alisson      2
# 2      Antonio      2
# 3       Coufal      1
# 4          DCL      1
# 5     Harrison      1
# 6   Iheanacho       1
# 7          KDB      1
# 8      Lingard      1
# 9       Lowton      1
# 10         Mee      1
# 11        Pope      1
# 12    Raphinha      1
# 13   Robertson      1
# 14      Taylor      1
# 15      Torres      1

# %%
import dataframe_image as dfi

# %%
GEE_differentials_sorted.dfi.export('PME_sorted.png')

# %%
PHY_differentials_sorted.dfi.export('PHY_sorted.png')
